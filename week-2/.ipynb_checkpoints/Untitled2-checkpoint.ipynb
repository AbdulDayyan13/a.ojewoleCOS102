# %% [markdown]
# Pseudocode for Store Checkout
#
# BEGIN
# SET total_price = 0
# WHILE customer-has-items
#     INPUT barcode
# PRINT product_name + ":" + product_price
# total_price = total_price + item_price
# END WHILE
#
# PRINT "Final Total:" + total_price
# END store checkout

# %% [markdown]
# Flowchart for Pseudocode![Screenshot 2026-03-09 233506.png](attachment:4d40508b-51d6-4b10-96a0-6e914594ae72.png)

# %% [markdown]
# Flowchart for Morning Routine
# <img src = "attachment:8e33e409-816f-425f-86e6-a100bf3dbc75.jpg" width = "600">

# %% [markdown]
# INPUT name1, age1
# INPUT name2, age2
#
# ASSIGN age1 to temp_age
# ASSIGN age2 to age1
# ASSIGN temp_age to age2
#
# PRINT name1,age1
# PRINT name1, age2
