# %% [markdown]
# Pseudocode for Female Table
#
# DECLARE Name[1 TO 10]: String
# DECLARE Age[1 TO 10]: Integer
# DECLARE Height[1 TO 10]:Floats
# DECLARE Score[1 TO 10]:Integers
#
# SET Name[1] TO "Evelyn"
# SET Age[1] TO 17
# SET Height[1] TO 5.5
# SET Score[1] TO 80
#
# SET Name[2] TO "Jessica"
# SET Age[2] TO 16
# SET Height[2] TO 6.0
# SET Score[2] TO 85
#
# SET Name[3] TO "Somto"
# SET Age[3] TO 17
# SET Height[3] TO 5.4
# SET Score[3] TO 70
#
# SET Name[4] TO "Edith"
# SET Age[4] TO 18
# SET Height[4] TO 5.9
# SET Score[4] TO 60
#
# SET Name[5] TO "Liza"
# SET Age[5] TO 16
# SET Height[5] TO 5.6
# SET Score[5] TO 76
#
# SET Name[6] TO "Madonna"
# SET Age[6] TO 18
# SET Height[6] TO 5.5
# SET Score[6] TO 66
#
# SET Name[7] TO "Waje"
# SET Age[7] TO 17
# SET Height[7] TO 6.1
# SET Score[7] TO 87
#
# SET Name[8] TO "Tola"
# SET Age[8] TO 20
# SET Height[8] TO 6.0
# SET Score[8] TO 95
#
# SET Name[9] TO "Aisha"
# SET Age[9] TO 19
# SET Height[9] TO 5.7
# SET Score[9] TO 50
#
# SET Name[10] TO "Latifa"
# SET Age[10] TO 49
# SET Height[10] TO 5.5
# SET Score[10] TO 49

# %%
#Python Code for Female Table - Tabulate Library Method 
names = ["Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Waje", "Tola", "Aisha", "Latifa"]
ages = [17, 16, 17, 18, 16, 18, 17, 20, 19, 17]
heights = [5.5, 6.0, 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5]
scores = [80, 85, 70, 60, 76, 66, 87, 95, 50, 49]


from tabulate import tabulate

data = list(zip(names, ages, heights, scores))

print(tabulate(data, headers=["Name", "Age", "Height", "Score"]))

# %% [markdown]
# Pseudocode for Male Table
#
# DECLARE TotalPeople: Integer
# SET TotalPeople TO 10
#
# FOR i = 1 TO TotalPeople
#     READ Names[i], Age[i], Height[i], Score[i]
# NEXT i
#
# OUTPUT "Names","Age","Height", "Score"
# FOR i TO TotalPeople
#     OUTPUT Names[i],Age[i],Height[i], Score[i]
# NEXT i
# END PROGRAM
#
# DATA "Chinuedu",19,5.7,74
# DATA "Liam",16,5.9,87
# DATA "Wale", 18, 5.8, 75
# DATA "Ggbenga",17,6.1,68
# DATA "Abiola",20,5.9,66
# DATA "Kola",19,5.5,78
# DATA "Kunle",16,6.1,87
# DATA "George",18,5.4,98
# DATA "Thomas",17,5.8,54
# DATA "Wesley",19,5.7,60

# %%
#Python Code for Male Table - Manual Method
names = ["Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas", "Wesley"]

ages = [19, 16, 18, 17, 20, 19, 16, 18, 17, 19]

heights = [5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7]

scores = [74, 87, 75, 68, 66, 78, 87, 98, 54, 60]


print(f"{'Name':<12} | {'Age':<5} | {'Height':<8} | {'Score':<5}")
print("-" * 44)

for n, a, h, s in zip(names, ages, heights, scores):
    print(f"{n:<12} | {a:<5} | {h:<8} | {s:<5}")
